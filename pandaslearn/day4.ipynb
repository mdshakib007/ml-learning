# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.rand(300, 10))

# %%
df
# Out:
#             0         1         2         3         4         5         6
# 0    0.100580  0.839766  0.730317  0.512358  0.187801  0.936423  0.470314  \
# 1    0.738420  0.440600  0.485049  0.976814  0.315541  0.375876  0.142957
# 2    0.180957  0.158739  0.084144  0.116833  0.902347  0.359525  0.844128
# 3    0.749646  0.784510  0.194037  0.827698  0.860443  0.723962  0.087069
# 4    0.841345  0.640155  0.310627  0.953938  0.148762  0.278239  0.045961
# ..        ...       ...       ...       ...       ...       ...       ...
# 295  0.982413  0.534054  0.085207  0.783854  0.911995  0.479965  0.064057
# 296  0.917420  0.393050  0.354130  0.470324  0.812578  0.692638  0.303464
# 297  0.388921  0.527334  0.444288  0.382760  0.105987  0.769301  0.543600
# 298  0.232429  0.501906  0.251195  0.217680  0.254130  0.620137  0.730936
# 299  0.887517  0.910606  0.354181  0.530172  0.179353  0.699448  0.056097
#
#             7         8         9
# 0    0.127645  0.953401  0.561274
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of             0         1         2         3         4         5         6
# 0    0.100580  0.839766  0.730317  0.512358  0.187801  0.936423  0.470314  \
# 1    0.738420  0.440600  0.485049  0.976814  0.315541  0.375876  0.142957
# 2    0.180957  0.158739  0.084144  0.116833  0.902347  0.359525  0.844128
# 3    0.749646  0.784510  0.194037  0.827698  0.860443  0.723962  0.087069
# 4    0.841345  0.640155  0.310627  0.953938  0.148762  0.278239  0.045961
# ..        ...       ...       ...       ...       ...       ...       ...
# 295  0.982413  0.534054  0.085207  0.783854  0.911995  0.479965  0.064057
# 296  0.917420  0.393050  0.354130  0.470324  0.812578  0.692638  0.303464
# 297  0.388921  0.527334  0.444288  0.382760  0.105987  0.769301  0.543600
# 298  0.232429  0.501906  0.251195  0.217680  0.254130  0.620137  0.730936
# 299  0.887517  0.910606  0.354181  0.530172  0.179353  0.699448  0.056097
#
#             7         8         9
# ...

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6
# 0  0.100580  0.839766  0.730317  0.512358  0.187801  0.936423  0.470314  \
# 1  0.738420  0.440600  0.485049  0.976814  0.315541  0.375876  0.142957
# 2  0.180957  0.158739  0.084144  0.116833  0.902347  0.359525  0.844128
# 3  0.749646  0.784510  0.194037  0.827698  0.860443  0.723962  0.087069
# 4  0.841345  0.640155  0.310627  0.953938  0.148762  0.278239  0.045961
#
#           7         8         9
# 0  0.127645  0.953401  0.561274
# 1  0.440626  0.936941  0.931661
# 2  0.301813  0.529219  0.999020
# 3  0.408803  0.951446  0.586134
# 4  0.645456  0.733218  0.120956

# %%
df.loc[0][0] = 345654

# %%
df
# Out:
#                  0         1         2         3         4         5
# 0    345654.000000  0.839766  0.730317  0.512358  0.187801  0.936423  \
# 1         0.738420  0.440600  0.485049  0.976814  0.315541  0.375876
# 2         0.180957  0.158739  0.084144  0.116833  0.902347  0.359525
# 3         0.749646  0.784510  0.194037  0.827698  0.860443  0.723962
# 4         0.841345  0.640155  0.310627  0.953938  0.148762  0.278239
# ..             ...       ...       ...       ...       ...       ...
# 295       0.982413  0.534054  0.085207  0.783854  0.911995  0.479965
# 296       0.917420  0.393050  0.354130  0.470324  0.812578  0.692638
# 297       0.388921  0.527334  0.444288  0.382760  0.105987  0.769301
# 298       0.232429  0.501906  0.251195  0.217680  0.254130  0.620137
# 299       0.887517  0.910606  0.354181  0.530172  0.179353  0.699448
#
#             6         7         8         9
# 0    0.470314  0.127645  0.953401  0.561274
# 1    0.142957  0.440626  0.936941  0.931661
# ...

# %%
df.drop(0, axis=1) # axis=0 - mean 'Y axis', axis=1 - mean 'X axis'
# Out:
#             1         2         3         4         5         6         7
# 0    0.839766  0.730317  0.512358  0.187801  0.936423  0.470314  0.127645  \
# 1    0.440600  0.485049  0.976814  0.315541  0.375876  0.142957  0.440626
# 2    0.158739  0.084144  0.116833  0.902347  0.359525  0.844128  0.301813
# 3    0.784510  0.194037  0.827698  0.860443  0.723962  0.087069  0.408803
# 4    0.640155  0.310627  0.953938  0.148762  0.278239  0.045961  0.645456
# ..        ...       ...       ...       ...       ...       ...       ...
# 295  0.534054  0.085207  0.783854  0.911995  0.479965  0.064057  0.364375
# 296  0.393050  0.354130  0.470324  0.812578  0.692638  0.303464  0.223401
# 297  0.527334  0.444288  0.382760  0.105987  0.769301  0.543600  0.378040
# 298  0.501906  0.251195  0.217680  0.254130  0.620137  0.730936  0.721852
# 299  0.910606  0.354181  0.530172  0.179353  0.699448  0.056097  0.639989
#
#             8         9
# 0    0.953401  0.561274
# 1    0.936941  0.931661
# ...

# %%
df.loc[[1, 2], [1,2]]
# Out:
#           1         2
# 1  0.440600  0.485049
# 2  0.158739  0.084144

# %%
df
# Out:
#                  0         1         2         3         4         5
# 0    345654.000000  0.839766  0.730317  0.512358  0.187801  0.936423  \
# 1         0.738420  0.440600  0.485049  0.976814  0.315541  0.375876
# 2         0.180957  0.158739  0.084144  0.116833  0.902347  0.359525
# 3         0.749646  0.784510  0.194037  0.827698  0.860443  0.723962
# 4         0.841345  0.640155  0.310627  0.953938  0.148762  0.278239
# ..             ...       ...       ...       ...       ...       ...
# 295       0.982413  0.534054  0.085207  0.783854  0.911995  0.479965
# 296       0.917420  0.393050  0.354130  0.470324  0.812578  0.692638
# 297       0.388921  0.527334  0.444288  0.382760  0.105987  0.769301
# 298       0.232429  0.501906  0.251195  0.217680  0.254130  0.620137
# 299       0.887517  0.910606  0.354181  0.530172  0.179353  0.699448
#
#             6         7         8         9
# 0    0.470314  0.127645  0.953401  0.561274
# 1    0.142957  0.440626  0.936941  0.931661
# ...

# %%
df = df.drop(0, axis=1)      # axis=0 - mean 'Y axis', axis=1 - mean 'X axis'

# %%
df
# Out:
#             1         2         3         4         5         6         7
# 0    0.839766  0.730317  0.512358  0.187801  0.936423  0.470314  0.127645  \
# 1    0.440600  0.485049  0.976814  0.315541  0.375876  0.142957  0.440626
# 2    0.158739  0.084144  0.116833  0.902347  0.359525  0.844128  0.301813
# 3    0.784510  0.194037  0.827698  0.860443  0.723962  0.087069  0.408803
# 4    0.640155  0.310627  0.953938  0.148762  0.278239  0.045961  0.645456
# ..        ...       ...       ...       ...       ...       ...       ...
# 295  0.534054  0.085207  0.783854  0.911995  0.479965  0.064057  0.364375
# 296  0.393050  0.354130  0.470324  0.812578  0.692638  0.303464  0.223401
# 297  0.527334  0.444288  0.382760  0.105987  0.769301  0.543600  0.378040
# 298  0.501906  0.251195  0.217680  0.254130  0.620137  0.730936  0.721852
# 299  0.910606  0.354181  0.530172  0.179353  0.699448  0.056097  0.639989
#
#             8         9
# 0    0.953401  0.561274
# 1    0.936941  0.931661
# ...

# %%
df.loc[[1,2], :]
# Out:
#           1         2         3         4         5         6         7
# 1  0.440600  0.485049  0.976814  0.315541  0.375876  0.142957  0.440626  \
# 2  0.158739  0.084144  0.116833  0.902347  0.359525  0.844128  0.301813
#
#           8         9
# 1  0.936941  0.931661
# 2  0.529219  0.999020

# %%
df.loc[(df[5] > 0.3)]     # the output is true in '5' column
# Out:
#             1         2         3         4         5         6         7
# 0    0.839766  0.730317  0.512358  0.187801  0.936423  0.470314  0.127645  \
# 1    0.440600  0.485049  0.976814  0.315541  0.375876  0.142957  0.440626
# 2    0.158739  0.084144  0.116833  0.902347  0.359525  0.844128  0.301813
# 3    0.784510  0.194037  0.827698  0.860443  0.723962  0.087069  0.408803
# 5    0.506044  0.035151  0.880974  0.452503  0.845782  0.735633  0.712050
# ..        ...       ...       ...       ...       ...       ...       ...
# 295  0.534054  0.085207  0.783854  0.911995  0.479965  0.064057  0.364375
# 296  0.393050  0.354130  0.470324  0.812578  0.692638  0.303464  0.223401
# 297  0.527334  0.444288  0.382760  0.105987  0.769301  0.543600  0.378040
# 298  0.501906  0.251195  0.217680  0.254130  0.620137  0.730936  0.721852
# 299  0.910606  0.354181  0.530172  0.179353  0.699448  0.056097  0.639989
#
#             8         9
# 0    0.953401  0.561274
# 1    0.936941  0.931661
# ...

# %%
df.loc[(df[3] > 0.5) & (df[4]<0.01)]     # look at the column 3 and column 4
# Out:
#             1         2         3         4         5         6         7
# 9    0.115380  0.811905  0.571657  0.009343  0.300632  0.393613  0.326271  \
# 193  0.788111  0.866245  0.789225  0.003677  0.273377  0.203770  0.845607
#
#             8         9
# 9    0.668417  0.048385
# 193  0.948504  0.857213

# %%
df.loc[(df[2] < 0.005) & (df[1] < 0.1)]
# Out:
# Empty DataFrame
# Columns: [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Index: []

# %%
df.iloc[1,2] # 1 number row and 3 number column
# Out:
# 0.9768143423113104

# %%
df.head(2)
# Out:
#           1         2         3         4         5         6         7
# 0  0.839766  0.730317  0.512358  0.187801  0.936423  0.470314  0.127645  \
# 1  0.440600  0.485049  0.976814  0.315541  0.375876  0.142957  0.440626
#
#           8         9
# 0  0.953401  0.561274
# 1  0.936941  0.931661

# %%
df.columns = list('ABCDEFGHI')

# %%
df
# Out:
#             A         B         C         D         E         F         G
# 0    0.839766  0.730317  0.512358  0.187801  0.936423  0.470314  0.127645  \
# 1    0.440600  0.485049  0.976814  0.315541  0.375876  0.142957  0.440626
# 2    0.158739  0.084144  0.116833  0.902347  0.359525  0.844128  0.301813
# 3    0.784510  0.194037  0.827698  0.860443  0.723962  0.087069  0.408803
# 4    0.640155  0.310627  0.953938  0.148762  0.278239  0.045961  0.645456
# ..        ...       ...       ...       ...       ...       ...       ...
# 295  0.534054  0.085207  0.783854  0.911995  0.479965  0.064057  0.364375
# 296  0.393050  0.354130  0.470324  0.812578  0.692638  0.303464  0.223401
# 297  0.527334  0.444288  0.382760  0.105987  0.769301  0.543600  0.378040
# 298  0.501906  0.251195  0.217680  0.254130  0.620137  0.730936  0.721852
# 299  0.910606  0.354181  0.530172  0.179353  0.699448  0.056097  0.639989
#
#             H         I
# 0    0.953401  0.561274
# 1    0.936941  0.931661
# ...

# %%
df.iloc[1,'D']     # this is not posible because 'iloc' is count by 'index'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:904, in _LocationIndexer._validate_tuple_indexer(self, key)
#     903 try:
# --> 904     self._validate_key(k, i)
#     905 except ValueError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:1518, in _iLocIndexer._validate_key(self, key, axis)
#    1517 else:
# -> 1518     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ...

# %%
df.loc[2,'D'] # row, column. 'loc - is search item by row and column name' . 'iloc - is search item by index'

# %%
df.iloc[[1,2], [3,4]]

# %%
df.head(1)
# Out:
#           A         B         C         D         E         F         G
# 0  0.839766  0.730317  0.512358  0.187801  0.936423  0.470314  0.127645  \
#
#           H         I
# 0  0.953401  0.561274

# %%
df.drop(0) # if we cannot store this value in a var, then we cannot find this new value later
# Out:
#             A         B         C         D         E         F         G
# 1    0.440600  0.485049  0.976814  0.315541  0.375876  0.142957  0.440626  \
# 2    0.158739  0.084144  0.116833  0.902347  0.359525  0.844128  0.301813
# 3    0.784510  0.194037  0.827698  0.860443  0.723962  0.087069  0.408803
# 4    0.640155  0.310627  0.953938  0.148762  0.278239  0.045961  0.645456
# 5    0.506044  0.035151  0.880974  0.452503  0.845782  0.735633  0.712050
# ..        ...       ...       ...       ...       ...       ...       ...
# 295  0.534054  0.085207  0.783854  0.911995  0.479965  0.064057  0.364375
# 296  0.393050  0.354130  0.470324  0.812578  0.692638  0.303464  0.223401
# 297  0.527334  0.444288  0.382760  0.105987  0.769301  0.543600  0.378040
# 298  0.501906  0.251195  0.217680  0.254130  0.620137  0.730936  0.721852
# 299  0.910606  0.354181  0.530172  0.179353  0.699448  0.056097  0.639989
#
#             H         I
# 1    0.936941  0.931661
# 2    0.529219  0.999020
# ...

# %%
df
# Out:
#             A         B         C         D         E         F         G
# 0    0.839766  0.730317  0.512358  0.187801  0.936423  0.470314  0.127645  \
# 1    0.440600  0.485049  0.976814  0.315541  0.375876  0.142957  0.440626
# 2    0.158739  0.084144  0.116833  0.902347  0.359525  0.844128  0.301813
# 3    0.784510  0.194037  0.827698  0.860443  0.723962  0.087069  0.408803
# 4    0.640155  0.310627  0.953938  0.148762  0.278239  0.045961  0.645456
# ..        ...       ...       ...       ...       ...       ...       ...
# 295  0.534054  0.085207  0.783854  0.911995  0.479965  0.064057  0.364375
# 296  0.393050  0.354130  0.470324  0.812578  0.692638  0.303464  0.223401
# 297  0.527334  0.444288  0.382760  0.105987  0.769301  0.543600  0.378040
# 298  0.501906  0.251195  0.217680  0.254130  0.620137  0.730936  0.721852
# 299  0.910606  0.354181  0.530172  0.179353  0.699448  0.056097  0.639989
#
#             H         I
# 0    0.953401  0.561274
# 1    0.936941  0.931661
# ...

# %%
df.drop(['A', 'D'], axis=1) # not change our data frame, this is just a view
# Out:
#             B         C         E         F         G         H         I
# 0    0.730317  0.512358  0.936423  0.470314  0.127645  0.953401  0.561274
# 1    0.485049  0.976814  0.375876  0.142957  0.440626  0.936941  0.931661
# 2    0.084144  0.116833  0.359525  0.844128  0.301813  0.529219  0.999020
# 3    0.194037  0.827698  0.723962  0.087069  0.408803  0.951446  0.586134
# 4    0.310627  0.953938  0.278239  0.045961  0.645456  0.733218  0.120956
# ..        ...       ...       ...       ...       ...       ...       ...
# 295  0.085207  0.783854  0.479965  0.064057  0.364375  0.170025  0.990317
# 296  0.354130  0.470324  0.692638  0.303464  0.223401  0.537200  0.667842
# 297  0.444288  0.382760  0.769301  0.543600  0.378040  0.171122  0.896666
# 298  0.251195  0.217680  0.620137  0.730936  0.721852  0.082796  0.583284
# 299  0.354181  0.530172  0.699448  0.056097  0.639989  0.649746  0.186884
#
# [300 rows x 7 columns]

# %%
df.drop(['I'], axis=1, inplace=True) # inplace method is delete the item permanently

# %%
df  # axis=0 - mean 'Y axis', axis=1 - mean 'X axis'
# Out:
#             A         B         C         D         E         F         G
# 0    0.839766  0.730317  0.512358  0.187801  0.936423  0.470314  0.127645  \
# 1    0.440600  0.485049  0.976814  0.315541  0.375876  0.142957  0.440626
# 2    0.158739  0.084144  0.116833  0.902347  0.359525  0.844128  0.301813
# 3    0.784510  0.194037  0.827698  0.860443  0.723962  0.087069  0.408803
# 4    0.640155  0.310627  0.953938  0.148762  0.278239  0.045961  0.645456
# ..        ...       ...       ...       ...       ...       ...       ...
# 295  0.534054  0.085207  0.783854  0.911995  0.479965  0.064057  0.364375
# 296  0.393050  0.354130  0.470324  0.812578  0.692638  0.303464  0.223401
# 297  0.527334  0.444288  0.382760  0.105987  0.769301  0.543600  0.378040
# 298  0.501906  0.251195  0.217680  0.254130  0.620137  0.730936  0.721852
# 299  0.910606  0.354181  0.530172  0.179353  0.699448  0.056097  0.639989
#
#             H
# 0    0.953401
# 1    0.936941
# 2    0.529219
# 3    0.951446
# ...

# %%
df.drop(['H'], axis=1, inplace=True)

# %%
df
# Out:
#             A         B         C         D         E         F         G
# 0    0.839766  0.730317  0.512358  0.187801  0.936423  0.470314  0.127645
# 1    0.440600  0.485049  0.976814  0.315541  0.375876  0.142957  0.440626
# 2    0.158739  0.084144  0.116833  0.902347  0.359525  0.844128  0.301813
# 3    0.784510  0.194037  0.827698  0.860443  0.723962  0.087069  0.408803
# 4    0.640155  0.310627  0.953938  0.148762  0.278239  0.045961  0.645456
# ..        ...       ...       ...       ...       ...       ...       ...
# 295  0.534054  0.085207  0.783854  0.911995  0.479965  0.064057  0.364375
# 296  0.393050  0.354130  0.470324  0.812578  0.692638  0.303464  0.223401
# 297  0.527334  0.444288  0.382760  0.105987  0.769301  0.543600  0.378040
# 298  0.501906  0.251195  0.217680  0.254130  0.620137  0.730936  0.721852
# 299  0.910606  0.354181  0.530172  0.179353  0.699448  0.056097  0.639989
#
# [300 rows x 7 columns]

# %%
df.head(2)
# Out:
#           A         B         C         D         E         F         G
# 0  0.839766  0.730317  0.512358  0.187801  0.936423  0.470314  0.127645
# 1  0.440600  0.485049  0.976814  0.315541  0.375876  0.142957  0.440626

# %%
df.drop([1,2], axis=0, inplace=True)

# %%
df
# Out:
#             A         B         C         D         E         F         G
# 0    0.839766  0.730317  0.512358  0.187801  0.936423  0.470314  0.127645
# 3    0.784510  0.194037  0.827698  0.860443  0.723962  0.087069  0.408803
# 4    0.640155  0.310627  0.953938  0.148762  0.278239  0.045961  0.645456
# 5    0.506044  0.035151  0.880974  0.452503  0.845782  0.735633  0.712050
# 6    0.827355  0.247915  0.189028  0.508934  0.369786  0.382032  0.711290
# ..        ...       ...       ...       ...       ...       ...       ...
# 295  0.534054  0.085207  0.783854  0.911995  0.479965  0.064057  0.364375
# 296  0.393050  0.354130  0.470324  0.812578  0.692638  0.303464  0.223401
# 297  0.527334  0.444288  0.382760  0.105987  0.769301  0.543600  0.378040
# 298  0.501906  0.251195  0.217680  0.254130  0.620137  0.730936  0.721852
# 299  0.910606  0.354181  0.530172  0.179353  0.699448  0.056097  0.639989
#
# [298 rows x 7 columns]

# %%
df.reset_index()   #this is replace index but 1 additional row will be added.
# Out:
#      index         A         B         C         D         E         F
# 0        0  0.839766  0.730317  0.512358  0.187801  0.936423  0.470314  \
# 1        3  0.784510  0.194037  0.827698  0.860443  0.723962  0.087069
# 2        4  0.640155  0.310627  0.953938  0.148762  0.278239  0.045961
# 3        5  0.506044  0.035151  0.880974  0.452503  0.845782  0.735633
# 4        6  0.827355  0.247915  0.189028  0.508934  0.369786  0.382032
# ..     ...       ...       ...       ...       ...       ...       ...
# 293    295  0.534054  0.085207  0.783854  0.911995  0.479965  0.064057
# 294    296  0.393050  0.354130  0.470324  0.812578  0.692638  0.303464
# 295    297  0.527334  0.444288  0.382760  0.105987  0.769301  0.543600
# 296    298  0.501906  0.251195  0.217680  0.254130  0.620137  0.730936
# 297    299  0.910606  0.354181  0.530172  0.179353  0.699448  0.056097
#
#             G
# 0    0.127645
# 1    0.408803
# 2    0.645456
# 3    0.712050
# 4    0.711290
# ..        ...
# ...

# %%
df.reset_index(drop=True) # this is complete the table, but this is just a view so my main table will not change.
# Out:
#             A         B         C         D         E         F         G
# 0    0.839766  0.730317  0.512358  0.187801  0.936423  0.470314  0.127645
# 1    0.784510  0.194037  0.827698  0.860443  0.723962  0.087069  0.408803
# 2    0.640155  0.310627  0.953938  0.148762  0.278239  0.045961  0.645456
# 3    0.506044  0.035151  0.880974  0.452503  0.845782  0.735633  0.712050
# 4    0.827355  0.247915  0.189028  0.508934  0.369786  0.382032  0.711290
# ..        ...       ...       ...       ...       ...       ...       ...
# 293  0.534054  0.085207  0.783854  0.911995  0.479965  0.064057  0.364375
# 294  0.393050  0.354130  0.470324  0.812578  0.692638  0.303464  0.223401
# 295  0.527334  0.444288  0.382760  0.105987  0.769301  0.543600  0.378040
# 296  0.501906  0.251195  0.217680  0.254130  0.620137  0.730936  0.721852
# 297  0.910606  0.354181  0.530172  0.179353  0.699448  0.056097  0.639989
#
# [298 rows x 7 columns]

# %%
df # not change
# Out:
#             A         B         C         D         E         F         G
# 0    0.839766  0.730317  0.512358  0.187801  0.936423  0.470314  0.127645
# 3    0.784510  0.194037  0.827698  0.860443  0.723962  0.087069  0.408803
# 4    0.640155  0.310627  0.953938  0.148762  0.278239  0.045961  0.645456
# 5    0.506044  0.035151  0.880974  0.452503  0.845782  0.735633  0.712050
# 6    0.827355  0.247915  0.189028  0.508934  0.369786  0.382032  0.711290
# ..        ...       ...       ...       ...       ...       ...       ...
# 295  0.534054  0.085207  0.783854  0.911995  0.479965  0.064057  0.364375
# 296  0.393050  0.354130  0.470324  0.812578  0.692638  0.303464  0.223401
# 297  0.527334  0.444288  0.382760  0.105987  0.769301  0.543600  0.378040
# 298  0.501906  0.251195  0.217680  0.254130  0.620137  0.730936  0.721852
# 299  0.910606  0.354181  0.530172  0.179353  0.699448  0.056097  0.639989
#
# [298 rows x 7 columns]

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#             A         B         C         D         E         F         G
# 0    0.839766  0.730317  0.512358  0.187801  0.936423  0.470314  0.127645
# 1    0.784510  0.194037  0.827698  0.860443  0.723962  0.087069  0.408803
# 2    0.640155  0.310627  0.953938  0.148762  0.278239  0.045961  0.645456
# 3    0.506044  0.035151  0.880974  0.452503  0.845782  0.735633  0.712050
# 4    0.827355  0.247915  0.189028  0.508934  0.369786  0.382032  0.711290
# ..        ...       ...       ...       ...       ...       ...       ...
# 293  0.534054  0.085207  0.783854  0.911995  0.479965  0.064057  0.364375
# 294  0.393050  0.354130  0.470324  0.812578  0.692638  0.303464  0.223401
# 295  0.527334  0.444288  0.382760  0.105987  0.769301  0.543600  0.378040
# 296  0.501906  0.251195  0.217680  0.254130  0.620137  0.730936  0.721852
# 297  0.910606  0.354181  0.530172  0.179353  0.699448  0.056097  0.639989
#
# [298 rows x 7 columns]

# %%
df.reset_index(drop=True, inplace=True)  #this is another way to get change the main

# %%
df
# Out:
#             A         B         C         D         E         F         G
# 0    0.839766  0.730317  0.512358  0.187801  0.936423  0.470314  0.127645
# 1    0.784510  0.194037  0.827698  0.860443  0.723962  0.087069  0.408803
# 2    0.640155  0.310627  0.953938  0.148762  0.278239  0.045961  0.645456
# 3    0.506044  0.035151  0.880974  0.452503  0.845782  0.735633  0.712050
# 4    0.827355  0.247915  0.189028  0.508934  0.369786  0.382032  0.711290
# ..        ...       ...       ...       ...       ...       ...       ...
# 293  0.534054  0.085207  0.783854  0.911995  0.479965  0.064057  0.364375
# 294  0.393050  0.354130  0.470324  0.812578  0.692638  0.303464  0.223401
# 295  0.527334  0.444288  0.382760  0.105987  0.769301  0.543600  0.378040
# 296  0.501906  0.251195  0.217680  0.254130  0.620137  0.730936  0.721852
# 297  0.910606  0.354181  0.530172  0.179353  0.699448  0.056097  0.639989
#
# [298 rows x 7 columns]

# %%
df['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 293    False
# 294    False
# 295    False
# 296    False
# 297    False
# Name: B, Length: 298, dtype: bool

# %%
df['B'] = None

# %%
df
# Out:
#             A     B         C         D         E         F         G
# 0    0.839766  None  0.512358  0.187801  0.936423  0.470314  0.127645
# 1    0.784510  None  0.827698  0.860443  0.723962  0.087069  0.408803
# 2    0.640155  None  0.953938  0.148762  0.278239  0.045961  0.645456
# 3    0.506044  None  0.880974  0.452503  0.845782  0.735633  0.712050
# 4    0.827355  None  0.189028  0.508934  0.369786  0.382032  0.711290
# ..        ...   ...       ...       ...       ...       ...       ...
# 293  0.534054  None  0.783854  0.911995  0.479965  0.064057  0.364375
# 294  0.393050  None  0.470324  0.812578  0.692638  0.303464  0.223401
# 295  0.527334  None  0.382760  0.105987  0.769301  0.543600  0.378040
# 296  0.501906  None  0.217680  0.254130  0.620137  0.730936  0.721852
# 297  0.910606  None  0.530172  0.179353  0.699448  0.056097  0.639989
#
# [298 rows x 7 columns]

# %%
df['B'] = 'i am shakib'

# %%
df
# Out:
#             A            B         C         D         E         F         G
# 0    0.839766  i am shakib  0.512358  0.187801  0.936423  0.470314  0.127645
# 1    0.784510  i am shakib  0.827698  0.860443  0.723962  0.087069  0.408803
# 2    0.640155  i am shakib  0.953938  0.148762  0.278239  0.045961  0.645456
# 3    0.506044  i am shakib  0.880974  0.452503  0.845782  0.735633  0.712050
# 4    0.827355  i am shakib  0.189028  0.508934  0.369786  0.382032  0.711290
# ..        ...          ...       ...       ...       ...       ...       ...
# 293  0.534054  i am shakib  0.783854  0.911995  0.479965  0.064057  0.364375
# 294  0.393050  i am shakib  0.470324  0.812578  0.692638  0.303464  0.223401
# 295  0.527334  i am shakib  0.382760  0.105987  0.769301  0.543600  0.378040
# 296  0.501906  i am shakib  0.217680  0.254130  0.620137  0.730936  0.721852
# 297  0.910606  i am shakib  0.530172  0.179353  0.699448  0.056097  0.639989
#
# [298 rows x 7 columns]

# %%
df.loc[:, ['B']] = 'This is the good way'

# %%
df
# Out:
#             A                     B         C         D         E         F
# 0    0.839766  This is the good way  0.512358  0.187801  0.936423  0.470314  \
# 1    0.784510  This is the good way  0.827698  0.860443  0.723962  0.087069
# 2    0.640155  This is the good way  0.953938  0.148762  0.278239  0.045961
# 3    0.506044  This is the good way  0.880974  0.452503  0.845782  0.735633
# 4    0.827355  This is the good way  0.189028  0.508934  0.369786  0.382032
# ..        ...                   ...       ...       ...       ...       ...
# 293  0.534054  This is the good way  0.783854  0.911995  0.479965  0.064057
# 294  0.393050  This is the good way  0.470324  0.812578  0.692638  0.303464
# 295  0.527334  This is the good way  0.382760  0.105987  0.769301  0.543600
# 296  0.501906  This is the good way  0.217680  0.254130  0.620137  0.730936
# 297  0.910606  This is the good way  0.530172  0.179353  0.699448  0.056097
#
#             G
# 0    0.127645
# 1    0.408803
# ...

# %%
df2 = pd.DataFrame(np.arange(199))

# %%
df2
# Out:
#        0
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
# ..   ...
# 194  194
# 195  195
# 196  196
# 197  197
# 198  198
#
# [199 rows x 1 columns]

# %%
df.dropna()
# Out:
#             A                     B         C         D         E         F
# 0    0.839766  This is the good way  0.512358  0.187801  0.936423  0.470314  \
# 1    0.784510  This is the good way  0.827698  0.860443  0.723962  0.087069
# 2    0.640155  This is the good way  0.953938  0.148762  0.278239  0.045961
# 3    0.506044  This is the good way  0.880974  0.452503  0.845782  0.735633
# 4    0.827355  This is the good way  0.189028  0.508934  0.369786  0.382032
# ..        ...                   ...       ...       ...       ...       ...
# 293  0.534054  This is the good way  0.783854  0.911995  0.479965  0.064057
# 294  0.393050  This is the good way  0.470324  0.812578  0.692638  0.303464
# 295  0.527334  This is the good way  0.382760  0.105987  0.769301  0.543600
# 296  0.501906  This is the good way  0.217680  0.254130  0.620137  0.730936
# 297  0.910606  This is the good way  0.530172  0.179353  0.699448  0.056097
#
#             G
# 0    0.127645
# 1    0.408803
# ...

# %%
df2 = pd.DataFrame({
    'name': [12,2345,234,12,23],
    'age': [345,2345,234,5,12]
})

# %%
df2
# Out:
#    name   age
# 0    12   345
# 1  2345  2345
# 2   234   234
# 3    12     5
# 4    23    12

# %%
df.drop_duplicates(subset=[1], keep='first') # an error occurred
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 df.drop_duplicates(subset=[1], keep='first')
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:6530, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6527 inplace = validate_bool_kwarg(inplace, "inplace")
#    6528 ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 6530 result = self[-self.duplicated(subset, keep=keep)]
#    6531 if ignore_index:
#    6532     result.index = default_index(len(result))
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:6662, in DataFrame.duplicated(self, subset, keep)
#    6660 diff = set(subset) - set(self.columns)
#    6661 if diff:
# -> 6662     raise KeyError(Index(diff))
#    6664 if len(subset) == 1 and self.columns.is_unique:
# ...

# %%
df.shape
# Out:
# (298, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298 entries, 0 to 297
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       298 non-null    float64
#  1   B       298 non-null    object
#  2   C       298 non-null    float64
#  3   D       298 non-null    float64
#  4   E       298 non-null    float64
#  5   F       298 non-null    float64
#  6   G       298 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 16.4+ KB

# %%
df['A'].value_counts()
# Out:
# A
# 0.839766    1
# 0.360321    1
# 0.324911    1
# 0.096994    1
# 0.408437    1
#            ..
# 0.269654    1
# 0.361539    1
# 0.880053    1
# 0.445728    1
# 0.910606    1
# Name: count, Length: 298, dtype: int64

# %%
df['A'].value_counts(dropna=False)
# Out:
# A
# 0.839766    1
# 0.360321    1
# 0.324911    1
# 0.096994    1
# 0.408437    1
#            ..
# 0.269654    1
# 0.361539    1
# 0.880053    1
# 0.445728    1
# 0.910606    1
# Name: count, Length: 298, dtype: int64
