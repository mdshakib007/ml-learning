# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('data_14.xlsx')        # need to 'pip3 install openpyxl'

# %%
df
# Out:
#      Order No Order Date        City  Account Manager Order Priority
# 0      5071-1 2013-05-05       Dhaka    Afifa Siddika         Medium  \
# 1      5071-2 2013-05-05       Dhaka    Afifa Siddika         Medium
# 2      5145-1 2013-06-29       Dhaka    Tabassum Khan            Low
# 3      5145-2 2013-06-29       Dhaka    Tabassum Khan            Low
# 4      5160-1 2013-07-05  Chittagong  Sajid Khandakar  Not Specified
# ...       ...        ...         ...              ...            ...
# 1034   6579-1 2017-02-03  Chittagong  Sajid Khandakar           High
# 1035   6581-1 2017-02-04       Dhaka    Sunayna Illin           High
# 1036   6582-1 2017-02-05       Dhaka      Farik Ahmed         Medium
# 1037   6584-1 2017-02-07  Chittagong  Sajid Khandakar            Low
# 1038   6586-1 2017-02-07  Chittagong  Sajid Khandakar         Medium
#
#                                   Product Name Product Category
# 0     Laser Neon Mac Format Diskettes, 10/Pack       Technology  \
# ...
