# %%
import pandas as pd

# %%
data = pd.read_excel('weatherdata.xlsx')

# %%
data
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%
# 0    2012-01-01 00:00:00    -1.8              -3.9         86  \
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 2    2012-01-01 02:00:00    -1.8              -3.4         89
# 3    2012-01-01 03:00:00    -1.5              -3.2         88
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa               Weather
# 0                   4            8.0     101.24                   Fog
# 1                   4            8.0     101.24                   Fog
# ...

# %%
data.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4  \
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data.shape
# Out:
# (8784, 8)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Date/Time           datetime64[ns]
# Temp_C                     float64
# Dew Point Temp_C           float64
# Rel Hum_%                    int64
# Wind Speed_km/h              int64
# Visibility_km              float64
# Press_kPa                  float64
# Weather                     object
# dtype: object

# %%
data['Weather'].unique() # this method is not applicable for entire dataframe
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
data['Temp_C'].unique()
# Out:
# array([ -1.8,  -1.5,  -1.4,  -1.3,  -1. ,  -0.5,  -0.2,   0.2,   0.8,
#          1.8,   2.6,   3. ,   3.8,   3.1,   3.2,   4. ,   4.4,   5.3,
#          5.2,   4.6,   3.9,   3.7,   2.9,   2.3,   2. ,   1.9,   1.5,
#          2.2,   1.7,   1.1,   0. ,  -0.7,  -2.1,  -4.1,  -4.8,  -5.6,
#         -5.8,  -7. ,  -7.4,  -9. ,  -9.7, -10.5, -11.3, -12.6, -12.9,
#        -13.3, -14. , -14.8, -15. , -15.3, -14.9, -15.1, -15.8, -16.3,
#        -16.9, -17.3, -17. , -17.1, -17.5, -17.9, -18.1, -18.5, -18.6,
#        -18.2, -17.8, -16.8, -15.2, -14.2, -13.7, -12.4, -10.2,  -9.4,
#         -8.9,  -8.4,  -7.8,  -7.6,  -9.5,  -9.6,  -8.8,  -7.5,  -5.4,
#         -5. ,  -8.2,  -7.1,  -6.1,  -6.6,  -6. ,  -4.7,  -4.4,  -5.1,
#         -4.3,  -6.7,  -9.2,  -9.8,  -9.9, -10. , -10.6, -11.8, -12. ,
#        -14.4, -12.3, -12.5, -11.7, -11.9, -11.2, -11.5, -11.6,  -9.3,
#         -8.7,  -8.5,  -8.1,  -6.9,  -6.4,  -5.7,  -5.5,  -3.7,  -3.6,
# ...

# %%
data.nunique() # this method is useable a column as well as entire dataframe
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
data['Press_kPa'].nunique() # single column
# Out:
# 518

# %%
data.count # we can use this command in a single column as well as entire dataframe
# Out:
# <bound method DataFrame.count of                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%
# 0    2012-01-01 00:00:00    -1.8              -3.9         86  \
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 2    2012-01-01 02:00:00    -1.8              -3.4         89
# 3    2012-01-01 03:00:00    -1.5              -3.2         88
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa               Weather
# 0                   4            8.0     101.24                   Fog
# ...

# %%
data['Weather'].count
# Out:
# <bound method Series.count of 0                        Fog
# 1                        Fog
# 2       Freezing Drizzle,Fog
# 3       Freezing Drizzle,Fog
# 4                        Fog
#                 ...
# 8779                    Snow
# 8780                    Snow
# 8781                    Snow
# 8782                    Snow
# 8783                    Snow
# Name: Weather, Length: 8784, dtype: object>

# %%
data.value_counts
# Out:
# <bound method DataFrame.value_counts of                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%
# 0    2012-01-01 00:00:00    -1.8              -3.9         86  \
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 2    2012-01-01 02:00:00    -1.8              -3.4         89
# 3    2012-01-01 03:00:00    -1.5              -3.2         88
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa               Weather
# 0                   4            8.0     101.24                   Fog
# ...

# %%
data['Weather'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                        Fog
# 1                        Fog
# 2       Freezing Drizzle,Fog
# 3       Freezing Drizzle,Fog
# 4                        Fog
#                 ...
# 8779                    Snow
# 8780                    Snow
# 8781                    Snow
# 8782                    Snow
# 8783                    Snow
# Name: Weather, Length: 8784, dtype: object>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   datetime64[ns]
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 549.1+ KB

# %% [markdown]
# ## Q1: Find all the unique 'wind speed' values in the data.

# %%
data.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4  \
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data['Wind Speed_km/h'].nunique()
# Out:
# 34

# %%
uws = data['Wind Speed_km/h'].unique()

# %%
uws
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %% [markdown]
# ## Q2: Find the number of times when the 'weather is exactly clear'

# %%
data.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4  \
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %% [markdown]
# ### first way

# %%
data.Weather.value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %% [markdown]
# ### filtering

# %%
data[data.Weather == 'Clear']
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%
# 67   2012-01-03 19:00:00   -16.9             -24.8         50  \
# 114  2012-01-05 18:00:00    -7.1             -14.4         56
# 115  2012-01-05 19:00:00    -9.2             -15.4         61
# 116  2012-01-05 20:00:00    -9.8             -15.7         62
# 117  2012-01-05 21:00:00    -9.0             -14.8         63
# ...                  ...     ...               ...        ...
# 8646 2012-12-26 06:00:00   -13.4             -14.8         89
# 8698 2012-12-28 10:00:00    -6.1              -8.6         82
# 8713 2012-12-29 01:00:00   -11.9             -13.6         87
# 8714 2012-12-29 02:00:00   -11.8             -13.1         90
# 8756 2012-12-30 20:00:00   -13.8             -16.5         80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather
# 67                 24           25.0     101.74   Clear
# 114                11           25.0     100.71   Clear
# ...

# %% [markdown]
# ### groupby()

# %%
data.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4  \
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data.groupby('Weather').get_group('Clear')
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%
# 67   2012-01-03 19:00:00   -16.9             -24.8         50  \
# 114  2012-01-05 18:00:00    -7.1             -14.4         56
# 115  2012-01-05 19:00:00    -9.2             -15.4         61
# 116  2012-01-05 20:00:00    -9.8             -15.7         62
# 117  2012-01-05 21:00:00    -9.0             -14.8         63
# ...                  ...     ...               ...        ...
# 8646 2012-12-26 06:00:00   -13.4             -14.8         89
# 8698 2012-12-28 10:00:00    -6.1              -8.6         82
# 8713 2012-12-29 01:00:00   -11.9             -13.6         87
# 8714 2012-12-29 02:00:00   -11.8             -13.1         90
# 8756 2012-12-30 20:00:00   -13.8             -16.5         80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather
# 67                 24           25.0     101.74   Clear
# 114                11           25.0     100.71   Clear
# ...

# %% [markdown]
# ## Q3: Find the number of times when the 'wind speed was exactly 4km/h

# %%
data.head()
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4  \
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 4 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.groupby('Wind Speed_km/h').get_group(4)# if any column name has the space, then we use this way, otherwise dot
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%
# 0    2012-01-01 00:00:00    -1.8              -3.9         86  \
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 96   2012-01-05 00:00:00    -8.8             -11.7         79
# 101  2012-01-05 05:00:00    -7.0              -9.5         82
# 146  2012-01-07 02:00:00    -8.1             -11.1         79
# ...                  ...     ...               ...        ...
# 8768 2012-12-31 08:00:00    -8.6             -10.3         87
# 8769 2012-12-31 09:00:00    -8.1              -9.6         89
# 8770 2012-12-31 10:00:00    -7.4              -8.9         89
# 8772 2012-12-31 12:00:00    -5.8              -7.5         88
# 8773 2012-12-31 13:00:00    -4.6              -6.6         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa       Weather
# 0                   4            8.0     101.24           Fog
# 1                   4            8.0     101.24           Fog
# ...

# %%
data[data['Wind Speed_km/h'] == 4] # if any column name has the space, then we use this way, otherwise dot
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%
# 0    2012-01-01 00:00:00    -1.8              -3.9         86  \
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 96   2012-01-05 00:00:00    -8.8             -11.7         79
# 101  2012-01-05 05:00:00    -7.0              -9.5         82
# 146  2012-01-07 02:00:00    -8.1             -11.1         79
# ...                  ...     ...               ...        ...
# 8768 2012-12-31 08:00:00    -8.6             -10.3         87
# 8769 2012-12-31 09:00:00    -8.1              -9.6         89
# 8770 2012-12-31 10:00:00    -7.4              -8.9         89
# 8772 2012-12-31 12:00:00    -5.8              -7.5         88
# 8773 2012-12-31 13:00:00    -4.6              -6.6         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa       Weather
# 0                   4            8.0     101.24           Fog
# 1                   4            8.0     101.24           Fog
# ...

# %% [markdown]
# ## Q4: Find out all the Null values in the data.

# %%
data[data.isnull()]
# Out:
#      Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h
# 0          NaT     NaN               NaN        NaN              NaN  \
# 1          NaT     NaN               NaN        NaN              NaN
# 2          NaT     NaN               NaN        NaN              NaN
# 3          NaT     NaN               NaN        NaN              NaN
# 4          NaT     NaN               NaN        NaN              NaN
# ...        ...     ...               ...        ...              ...
# 8779       NaT     NaN               NaN        NaN              NaN
# 8780       NaT     NaN               NaN        NaN              NaN
# 8781       NaT     NaN               NaN        NaN              NaN
# 8782       NaT     NaN               NaN        NaN              NaN
# 8783       NaT     NaN               NaN        NaN              NaN
#
#       Visibility_km  Press_kPa Weather
# 0               NaN        NaN     NaN
# 1               NaN        NaN     NaN
# ...

# %%
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# ## Q5: Rename the column name 'weather' to 'weather condition'

# %%
data.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4  \
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data.rename(columns= {'Weather': 'Weather Condition'})
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%
# 0    2012-01-01 00:00:00    -1.8              -3.9         86  \
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 2    2012-01-01 02:00:00    -1.8              -3.4         89
# 3    2012-01-01 03:00:00    -1.5              -3.2         88
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa     Weather Condition
# 0                   4            8.0     101.24                   Fog
# 1                   4            8.0     101.24                   Fog
# ...

# %%
#if i need to rename column permanently then use 'inplace=True'

# %%
data.rename(columns={'Weather':'Weather Condition'}, inplace= True)

# %%
data
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%
# 0    2012-01-01 00:00:00    -1.8              -3.9         86  \
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 2    2012-01-01 02:00:00    -1.8              -3.4         89
# 3    2012-01-01 03:00:00    -1.5              -3.2         88
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa     Weather Condition
# 0                   4            8.0     101.24                   Fog
# 1                   4            8.0     101.24                   Fog
# ...

# %% [markdown]
# ## Q6: what is the mean 'Visibility'?

# %%
data.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4  \
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data['Visibility_km'].mean()
# Out:
# 27.664446721311478

# %% [markdown]
# ## what is the standard deviation of 'Pressuer' in this data?

# %%
data.Press_kPa.std() # if any column name has the space, then we use this way, otherwise dot
# Out:
# 0.8440047459486483

# %% [markdown]
# # what is the variance of 'relative humidity' in this data?

# %%
data.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4  \
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data['Rel Hum_%'].var()  # if any column name has the space, then we use this way, otherwise dot
# Out:
# 286.24855019850196

# %% [markdown]
# ## find all instances when 'snow' was recorded.

# %%
# value count
data.head()
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4  \
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 4 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather Condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data['Weather Condition'].value_counts()
# Out:
# Weather Condition
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
# filtering
data[data['Weather Condition'] == 'Snow']
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%
# 55   2012-01-03 07:00:00   -14.0             -19.5         63  \
# 84   2012-01-04 12:00:00   -13.7             -21.7         51
# 86   2012-01-04 14:00:00   -11.3             -19.0         53
# 87   2012-01-04 15:00:00   -10.2             -16.3         61
# 88   2012-01-04 16:00:00    -9.4             -15.5         61
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Condition
# 55                 19           25.0     100.95              Snow
# 84                 11           24.1     101.25              Snow
# ...

# %%
# str.contains
data[data['Weather Condition'].str.contains('Snow')]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%
# 41   2012-01-02 17:00:00    -2.1              -9.5         57  \
# 44   2012-01-02 20:00:00    -5.6             -13.4         54
# 45   2012-01-02 21:00:00    -5.8             -12.8         58
# 47   2012-01-02 23:00:00    -7.4             -14.1         59
# 48   2012-01-03 00:00:00    -9.0             -16.0         57
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Condition
# 41                 22           25.0      99.66      Snow Showers
# 44                 24           25.0     100.07      Snow Showers
# ...

# %% [markdown]
# ## find all instances when 'wind speed is above 24' and 'visibility is 25'

# %%
data.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4  \
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data[(data['Wind Speed_km/h'] > 24) & (data['Visibility_km'] == 25)]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%
# 23   2012-01-01 23:00:00     5.3               2.0         79  \
# 24   2012-01-02 00:00:00     5.2               1.5         77
# 25   2012-01-02 01:00:00     4.6               0.0         72
# 26   2012-01-02 02:00:00     3.9              -0.9         71
# 27   2012-01-02 03:00:00     3.7              -1.5         69
# ...                  ...     ...               ...        ...
# 8705 2012-12-28 17:00:00    -8.6             -12.0         76
# 8753 2012-12-30 17:00:00   -12.1             -15.8         74
# 8755 2012-12-30 19:00:00   -13.4             -16.5         77
# 8759 2012-12-30 23:00:00   -12.1             -15.1         78
# 8760 2012-12-31 00:00:00   -11.1             -14.4         77
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Condition
# 23                 30           25.0      99.31            Cloudy
# 24                 35           25.0      99.26      Rain Showers
# ...
